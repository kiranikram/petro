# %%
import pandas as pd

# %% [markdown]
# ## Task 1 Results:

# %%
merged_data = pd.read_csv("data/new_merged.csv")

# %%
merged_data.drop('Unnamed: 0',axis=1,inplace=True)
merged_data.head()
# Out:
#               Datetime  TenMin_Price  Hourly_Price  Day_Price
# 0  2021-11-01 08:00:00     71.414583       71.5125       66.1
# 1  2021-11-01 10:00:00     70.347917       69.5750       66.1
# 2  2021-11-01 12:00:00     65.541667       64.6500       66.1
# 3  2021-11-01 14:00:00     64.685417       64.5750       66.1
# 4  2021-11-01 16:00:00     65.187500       67.0000       66.1

# %% [markdown]
# ## Task 2 Consumption Plot:

# %%
# %pylab inline
import matplotlib. pyplot as plt
import matplotlib. image as mpimg
img = mpimg. imread('data/consumption_plot.png')
imgplot = plt. imshow(img)
plt. show()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Across the years there is a clear trend of greater consumption in the winter months. Consumption seems to increase as it gets colder.

# %% [markdown]
# Task 3: Code can be found in robot.py

# %% [markdown]
# Task 4: Code can be found in trades.py
